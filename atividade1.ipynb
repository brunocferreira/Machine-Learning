# %%
#--- Libraries ---#
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris = pd.read_csv('./lib/iris/iris.data') # https://archive.ics.uci.edu/dataset/53/iris
iris.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
iris.columns = [
  'sepal_length_in_cm',
  'sepal_width_in_cm',
  'petal_length _in_cm',
  'petal_width_in_cm',
  'class'
  ]
iris
# Out:
#      sepal_length_in_cm  sepal_width_in_cm  petal_length _in_cm
# 0                   4.9                3.0                  1.4  \
# 1                   4.7                3.2                  1.3
# 2                   4.6                3.1                  1.5
# 3                   5.0                3.6                  1.4
# 4                   5.4                3.9                  1.7
# ..                  ...                ...                  ...
# 144                 6.7                3.0                  5.2
# 145                 6.3                2.5                  5.0
# 146                 6.5                3.0                  5.2
# 147                 6.2                3.4                  5.4
# 148                 5.9                3.0                  5.1
#
#      petal_width_in_cm           class
# 0                  0.2     Iris-setosa
# 1                  0.2     Iris-setosa
# 2                  0.2     Iris-setosa
# ...

# %%
classes, tipos = iris.iloc[:, -1].factorize()
iris['classe'] = classes
iris
# Out:
#      sepal_length_in_cm  sepal_width_in_cm  petal_length _in_cm
# 0                   4.9                3.0                  1.4  \
# 1                   4.7                3.2                  1.3
# 2                   4.6                3.1                  1.5
# 3                   5.0                3.6                  1.4
# 4                   5.4                3.9                  1.7
# ..                  ...                ...                  ...
# 144                 6.7                3.0                  5.2
# 145                 6.3                2.5                  5.0
# 146                 6.5                3.0                  5.2
# 147                 6.2                3.4                  5.4
# 148                 5.9                3.0                  5.1
#
#      petal_width_in_cm           class  classe
# 0                  0.2     Iris-setosa       0
# 1                  0.2     Iris-setosa       0
# 2                  0.2     Iris-setosa       0
# ...

# %%
sns.pairplot(iris, hue = 'class', height=1.5)

# %%
x_iris = iris.drop(['class', 'classe'], axis=1)
x_iris.shape
# Out:
# (149, 4)

# %%
y_iris = iris['classe']
y_iris.shape
# Out:
# (149,)

# %%
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.naive_bayes import GaussianNB as NB

# %%
classificador = 3

# %%
#from sklearn.neighbors import KNeighborsClassifier as KNN

knn = KNN(n_neighbors=classificador)

knn.fit(x_iris,y_iris)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
find_array = np.random.rand(1,4)
find_array = find_array*100
found = knn.predict(find_array)
print(f'find_array: {find_array}')
print(f'found: {found}')
# Out:
# find_array: [[69.46235005 69.04974276  7.20493841 41.41490834]]
# found: [2]
# c:\Users\bruno\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
# from sklearn.naive_bayes import GaussianNB as NB
clf = NB()
clf.fit(x_iris,y_iris)
# Out:
# GaussianNB()

# %%
clf.predict(find_array)
# Out:
# c:\Users\bruno\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# array([2], dtype=int64)

# %%
bupa = pd.read_csv('./lib/liver/bupa.data') # https://archive.ics.uci.edu/dataset/60/liver+disorders
bupa.head()
# Out:
#    85  92  45  27  31  0.0  1
# 0  85  64  59  32  23  0.0  2
# 1  86  54  33  16  54  0.0  2
# 2  91  78  34  24  36  0.0  2
# 3  87  70  12  28  10  0.0  2
# 4  98  55  13  17  17  0.0  2

# %%
bupa.columns = [
  'mean_corpuscular_volume',
  'alkaline_phosphotase',
  'alanine_aminotransferase',
  'aspartate_aminotransferase',
  'gamma-glutamyl_transpeptidase',
  'drunk_per_day',
  'BUPA_researchers'
  ]
bupa
# Out:
#      mean_corpuscular_volume  alkaline_phosphotase  alanine_aminotransferase
# 0                         85                    64                        59  \
# 1                         86                    54                        33
# 2                         91                    78                        34
# 3                         87                    70                        12
# 4                         98                    55                        13
# ..                       ...                   ...                       ...
# 339                       99                    75                        26
# 340                       96                    69                        53
# 341                       98                    77                        55
# 342                       91                    68                        27
# 343                       98                    99                        57
#
# ...

# %%
sns.pairplot(bupa, hue = 'BUPA_researchers', height=1.5)

# %%
x_bupa = bupa.drop('BUPA_researchers', axis=1)
x_bupa.shape
# Out:
# (344, 6)

# %%
y_bupa = bupa['BUPA_researchers']
y_bupa.shape
# Out:
# (344,)

# %%
classificador = 3

knn = KNN(n_neighbors=classificador)

knn.fit(x_bupa,y_bupa)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
find_array = np.random.rand(1,6)
find_array = find_array*100
found = knn.predict(find_array)
print(f'find_array: {find_array}')
print(f'found: {found}')
# Out:
# find_array: [[47.67428438 62.27189847 63.53756738 58.61436719 94.19390579 49.62882697]]
# found: [2]
# c:\Users\bruno\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
clf = NB()
clf.fit(x_bupa,y_bupa)
# Out:
# GaussianNB()

# %%
clf.predict(find_array)
# Out:
# c:\Users\bruno\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)
